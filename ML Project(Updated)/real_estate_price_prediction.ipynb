# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import ipywidgets as widgets
from IPython.display import display

# %%
model = joblib.load("real_estate_price_predictor.pkl")

# %%
preprocessing_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])

# %%
feature_names = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 
    'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'
]

# %%
input_widgets = {}
for feature in feature_names:
    input_widgets[feature] = widgets.FloatText(description=feature)

# %%
import ipywidgets as widgets

output = widgets.Output()

def predict_price(button):

    # Clear output
    output.clear_output()

    print("Predict button clicked.")

    # Get user inputs
    user_inputs = {
        feature: input_widgets[feature].value
        for feature in feature_names
    }

    print("User inputs collected:", user_inputs)

    user_input_df = pd.DataFrame(user_inputs, index=[0])

    # Preprocess
    user_input_prepared = preprocessing_pipeline.transform(user_input_df)

    print("Preprocessed inputs:", user_input_prepared)

    # Predict
    prediction = model.predict(user_input_prepared)

    # Display prediction
    with output:
        print(f"Predicted Price: ${prediction[0]:,.2f}")

display(output)
# Out:
# Output()

# %%
predict_button = widgets.Button(description="Predict Price")
predict_button.on_click(predict_price)

# %%
for widget in input_widgets.values():
    display(widget)
display(predict_button)
# Out:
# FloatText(value=0.0, description='CRIM')
# FloatText(value=0.0, description='ZN')
# FloatText(value=0.0, description='INDUS')
# FloatText(value=0.0, description='CHAS')
# FloatText(value=0.0, description='NOX')
# FloatText(value=0.0, description='RM')
# FloatText(value=0.0, description='AGE')
# FloatText(value=0.0, description='DIS')
# FloatText(value=0.0, description='RAD')
# FloatText(value=0.0, description='TAX')
# FloatText(value=0.0, description='PTRATIO')
# FloatText(value=0.0, description='B')
# FloatText(value=0.0, description='LSTAT')
# Button(description='Predict Price', style=ButtonStyle())

# %%
output = widgets.Output()
display(output)
# Out:
# Output()
